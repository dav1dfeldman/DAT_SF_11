# %%
# %matplotlib inline

import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline
from sklearn.cross_validation import train_test_split
import pandas as pd
import matplotlib.pylab as plt
from IPython.core.pylabtools import figsize
figsize(5,5)
plt.style.use('fivethirtyeight')

# %%
import pandas as pd
from pandas import DataFrame
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
fig, ax = plt.subplots(1,1)
ax.scatter(df.cylinders, df.mpg);

# %%
threedee = plt.figure().gca(projection='3d')
threedee.scatter(features, cylinders, target)
threedee.set_xlabel('weight')
threedee.set_ylabel('cylinders')
threedee.set_zlabel('mpg')
plt.show();

# %%
np.random.seed(1)

# %%
#fig, ax = plt.subplots(1,1)
#ax.scatter(df.weight, df.mpg);

for i in range(1,4):
    z = np.polyfit(df.weight, df.mpg, i)
    p = np.poly1d(z)
    
    #print "Polynomial (" + str(i) + ")", '\n', p, '\n'
    xp = np.linspace(1500, max(df.weight), max(df.mpg))
    plt.plot(df.weight, df.mpg, '.', xp, p(xp), '-')

# %%
df = pd.read_csv('../data/auto_mpg.txt', delimiter = '\t')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 398 entries, 0 to 397
# Data columns (total 9 columns):
# mpg             398 non-null float64
# cylinders       398 non-null int64
# displacement    398 non-null float64
# horsepower      398 non-null object
# weight          398 non-null int64
# acceleration    398 non-null float64
# model           398 non-null int64
# origin          398 non-null int64
# car_name        398 non-null object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 31.1+ KB

# %%
df = df[['weight', 'cylinders', 'mpg']]
df.info()
rows = np.random.choice(df.index.values, 398)
sampled_df = df.ix[rows]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 398 entries, 0 to 397
# Data columns (total 3 columns):
# weight       398 non-null int64
# cylinders    398 non-null int64
# mpg          398 non-null float64
# dtypes: float64(1), int64(2)
# memory usage: 12.4 KB

# %%
sampled_df.sort(columns = 'weight', ascending = True, inplace = True)
# Out:
# /Users/David/anaconda/lib/python2.7/site-packages/pandas/core/frame.py:2798: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   inplace=inplace, kind=kind, na_position=na_position)

# %%
features = sampled_df['weight'].values

# %%
cylinders = sampled_df['cylinders'].values

# %%
target = sampled_df.mpg.values

# %%
features_train, features_test, target_train, target_test = train_test_split(features, target, test_size = 0.2)

# %%
target_train
# Out:
# array([ 27.2,  39. ,  26. ,  26. ,  20. ,  28. ,  24. ,  25. ,  28. ,
#         24. ,  28. ,  40.8,  22. ,   9. ,  13. ,  25. ,  31. ,  24. ,
#         14. ,  36. ,  22.5,  29.5,  16.5,  28. ,  26. ,  31. ,  44.3,
#         20.5,  21. ,  16. ,  15. ,  14. ,  13. ,  16.5,  20.2,  30. ,
#         13. ,  22. ,  13. ,  18. ,  32. ,  16. ,  37. ,  32. ,  33.5,
#         28. ,  22. ,  34.5,  14. ,  35. ,  19.8,  30. ,  13. ,  29.5,
#         20. ,  17.6,  23.2,  13. ,  15.5,  28. ,  32.2,  20.5,  25.4,
#         16.5,  27. ,  35. ,  18. ,  17. ,  30.5,  19. ,  24. ,  20. ,
#         38. ,  22. ,  28. ,  23. ,  20.2,  36. ,  27.2,  14. ,  18. ,
#         20.5,  18. ,  31. ,  34.3,  41.5,  28. ,  18. ,  29. ,  29.9,
#         16. ,  15. ,  32. ,  18. ,  30.5,  32.8,  13. ,  21. ,  22. ,
#         19. ,  22.5,  26. ,  15.5,  40.9,  32. ,  28. ,  15.5,  14.5,
#         27. ,  28. ,  29.8,  13. ,  33.5,  13. ,  30.9,  23. ,  15. ,
#         14. ,  13. ,  20. ,  29. ,  21. ,  19.8,  10. ,  33. ,  25. ,
#         29.5,  34.3,  33.8,  24. ,  21. ,  31.8,  16. ,  13. ,  14. ,
#         23.9,  21.5,  32. ,  16.5,  18. ,  33.5,  25.5,  18. ,  31.5,
#         31. ,  15. ,  19. ,  16. ,  20.5,  17.5,  27.2,  14. ,  29. ,
#         13. ,  32.4,  20.8,  24.3,  26. ,  34.2,  17. ,  19. ,  16. ,
#         19. ,  15. ,  13. ,  15. ,  28. ,  24.5,  27.2,  37.7,  25.8,
#         20. ,  16. ,  24. ,  26. ,  34.5,  13. ,  25.8,  32. ,  30. ,
#         18. ,  17. ,  34. ,  23.6,  19. ,  28. ,  15. ,  22. ,  36. ,
#         13. ,  15. ,  33. ,  26.5,  12. ,  30. ,  28. ,  32. ,  17.7,
#         17.5,  39.1,  23. ,  22.3,  18. ,  13. ,  15. ,  26. ,  25. ,
#         32. ,  21.6,  13. ,  20.5,  27.2,  29.5,  19. ,  31.5,  31. ,
#         34.1,  35.7,  19. ,  29. ,  18. ,  20.5,  18. ,  10. ,  34. ,
#         13. ,  16.5,  13. ,  29.5,  19. ,  32.4,  26. ,  13. ,  17.5,
#         37. ,  19. ,  15. ,  31. ,  21.6,  28. ,  14. ,  15. ,  29. ,
#         32. ,  36. ,  13. ,  36.1,  20. ,  34. ,  30. ,  14. ,  25. ,
#         19. ,  21. ,  13. ,  25. ,  38.1,  22. ,  28. ,  18. ,  21.5,
#         31. ,  11. ,  18. ,  32.7,  25. ,  30.5,  28. ,  13. ,  13. ,
#         29. ,  24. ,  19. ,  31. ,  16. ,  26. ,  34.1,  27.4,  13. ,
#         15. ,  25. ,  26. ,  36. ,  31. ,  19. ,  23. ,  20.2,  43.1,
#         27. ,  36.4,  19.9,  31.3,  27. ,  27. ,  19.1,  29. ,  31. ,
#         16. ,  26. ,  23.8,  15.5,  31.5,  16. ,  20. ,  29.8,  29. ,
#         24.2,  15. ,  13. ,  19. ,  43.4,  32. ,  18.2,  20.6,  15.5,
#         19.2,  26. ,  35. ])

# %%
features_train_2D = features_train.reshape(80, -1)
features_train_2D
# Out:
# array([[1955,    4],
#        [1825,    4],
#        [2740,    4],
#        [2835,    6],
#        [3651,    6],
#        [4278,    8],
#        [2833,    6],
#        [2950,    5],
#        [3121,    6],
#        [4699,    8],
#        [4380,    8],
#        [1795,    4],
#        [2144,    4],
#        [3085,    6],
#        [2672,    4],
#        [2672,    4],
#        [3821,    8],
#        [1965,    4],
#        [3211,    6],
#        [2188,    4],
#        [4746,    8],
#        [1800,    4],
#        [2395,    4],
#        [2380,    4],
#        [4735,    8],
#        [2370,    4],
#        [2525,    4],
#        [3155,    6],
#        [1795,    4],
#        [3190,    4],
#        [4257,    8],
#        [2615,    4],
#        [2320,    4],
#        [2290,    4],
#        [2592,    4],
#        [4615,    8],
#        [2511,    4],
#        [3821,    8],
#        [4077,    8],
#        [1845,    4],
#        [2160,    4],
#        [2464,    4],
#        [2200,    4],
#        [2720,    4],
#        [2155,    4],
#        [2065,    4],
#        [2246,    4],
#        [2085,    4],
#        [2489,    4],
#        [2155,    4],
#        [2190,    4],
#        [2933,    4],
#        [2430,    4],
#        [2572,    4],
#        [3264,    6],
#        [3563,    8],
#        [1945,    4],
#        [3230,    4],
#        [3445,    6],
#        [2264,    4],
#        [2670,    4],
#        [2220,    4],
#        [2265,    4],
#        [2648,    6],
#        [2511,    4],
#        [3563,    8],
#        [3574,    6],
#        [1755,    4],
#        [2278,    4],
#        [2620,    4],
#        [2300,    4],
#        [3264,    6],
#        [2930,    6],
#        [2230,    4],
#        [1613,    4],
#        [2490,    4],
#        [3425,    8],
#        [2962,    6],
#        [3012,    6],
#        [2490,    4]])

# %%
features_train_1D = features_train.reshape((-1,))
#features_train_1D
#features_train_1D = features_train.reshape((-1, 1))
# Out:
# array([1955,    4, 1825,    4, 2740,    4, 2835,    6, 3651,    6, 4278,
#           8, 2833,    6, 2950,    5, 3121,    6, 4699,    8, 4380,    8,
#        1795,    4, 2144,    4, 3085,    6, 2672,    4, 2672,    4, 3821,
#           8, 1965,    4, 3211,    6, 2188,    4, 4746,    8, 1800,    4,
#        2395,    4, 2380,    4, 4735,    8, 2370,    4, 2525,    4, 3155,
#           6, 1795,    4, 3190,    4, 4257,    8, 2615,    4, 2320,    4,
#        2290,    4, 2592,    4, 4615,    8, 2511,    4, 3821,    8, 4077,
#           8, 1845,    4, 2160,    4, 2464,    4, 2200,    4, 2720,    4,
#        2155,    4, 2065,    4, 2246,    4, 2085,    4, 2489,    4, 2155,
#           4, 2190,    4, 2933,    4, 2430,    4, 2572,    4, 3264,    6,
#        3563,    8, 1945,    4, 3230,    4, 3445,    6, 2264,    4, 2670,
#           4, 2220,    4, 2265,    4, 2648,    6, 2511,    4, 3563,    8,
#        3574,    6, 1755,    4, 2278,    4, 2620,    4, 2300,    4, 3264,
#           6, 2930,    6, 2230,    4, 1613,    4, 2490,    4, 3425,    8,
#        2962,    6, 3012,    6, 2490,    4])

# %%
# doesn't make sense to plot the 'ground truth' because the line looks crazy...

#fig,ax = plt.subplots(1,1)
#ax.plot(features_train, target_train, label='ground truth', color='green')

# %%
fig,ax = plt.subplots(1,1)
ax.scatter(features_train, target_train, label='data', s=30)
ax.set_ylabel('y')
ax.set_xlabel('x')
ax.legend()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-62-918bde91f4de> in <module>()
#       1 fig,ax = plt.subplots(1,1)
# ----> 2 ax.scatter(features_train, target_train, label='data', s=30)
#       3 ax.set_ylabel('y')
#       4 ax.set_xlabel('x')
#       5 ax.legend()
#
# /Users/David/anaconda/lib/python2.7/site-packages/matplotlib/axes/_axes.pyc in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, **kwargs)
#    3575         y = np.ma.ravel(y)
#    3576         if x.size != y.size:
# -> 3577             raise ValueError("x and y must be the same size")
#    3578
#    3579         s = np.ma.ravel(s)  # This doesn't have to match x, y in size.
#
# ValueError: x and y must be the same size

# %%
target
# Out:
# array([ 31. ,  29.5,  31. ,  32. ,  30. ,  31. ,  29. ,  31.5,  31.5,
#         37.7,  30.5,  28. ,  29.5,  29.5,  34.5,  30. ,  24.5,  28. ,
#         34.3,  36. ,  29. ,  29. ,  25. ,  23. ,  28. ,  26. ,  32.2,
#         32. ,  26. ,  19. ,  19. ,  32.4,  36. ,  25. ,  25. ,  29.9,
#         34. ,  21. ,  35. ,  29. ,  31.3,  33.5,  28. ,  32.9,  28. ,
#         32. ,  28. ,  28. ,  28. ,  25.1,  21.5,  27. ,  27. ,  21.6,
#         22. ,  22. ,  21. ,  22.3,  23.6,  32.7,  18. ,  23. ,  20.2,
#         19.8,  19.8,  38. ,  20.8,  15. ,  13. ,  18.1,  21.5,  19. ,
#         18. ,  19.1,  15. ,  20.5,  16. ,  18. ,  25.4,  19.2,  14. ,
#         15. ,  13. ,  16. ,  18.2,  15. ,  13. ,  17.5,  15. ,  15. ,
#         16. ,  14.5,  13. ,  14. ,  10. ,  13. ,  10. ,  16. ,  13. ,  12. ])

# %%
fig,ax = plt.subplots(1,1)

ax.scatter(features_train, target_train, s = 30)

# %%
features_train.shape
# Out:
# (80,)

# %%
target_train.shape
# Out:
# (80,)

# %%
def plot_approximation(est, ax, label=None):
    """Plot the approximation of ``est`` on axis ``ax``. """
    ax.scatter(features_train_2D, target_train, s=100)
    
# what do i have to do to plot the regression line??

# %%
fig,ax = plt.subplots(1,1)
degree = 3
est = make_pipeline(PolynomialFeatures(degree), LinearRegression())
plot_approximation(est, ax, label='degree=%d' % degree)

# %%
features_train_2D.shape
# Out:
# (80, 1)

# %%
target_train.shape
# Out:
# (80,)

# %%
est.fit(features_train_2D, target_train) # fit runs the linear regression
# Out:
# Pipeline(steps=[('polynomialfeatures', PolynomialFeatures(degree=3, include_bias=True, interaction_only=False)), ('linearregression', LinearRegression(copy_X=True, fit_intercept=True, normalize=False))])

# %%
fig, ax = plt.subplots(1, 1)
ax.scatter(features, est.predict(features.reshape(-1, 1)), color = 'r')
ax.scatter(features, target, color='b')

# %%
est.predict(features.reshape(-1, 1))
# Out:
# array([ 31.38517547,  31.13555768,  30.73814577,  30.67920048,
#         30.5970287 ,  30.53275706,  30.37417078,  30.32668599,
#         30.32668599,  30.30258701,  30.29773883,  29.92444807,
#         29.8577206 ,  29.8577206 ,  29.77256052,  29.74374651,
#         29.69134855,  29.69134855,  29.54831871,  29.44415414,
#         29.35663289,  29.35663289,  29.35032203,  29.35032203,
#         29.06499167,  29.05833619,  29.05833619,  28.85525209,
#         28.82077105,  28.61018865,  28.61018865,  28.46636562,
#         28.31988171,  28.28285371,  28.28285371,  28.24566522,
#         28.13314851,  28.08774739,  27.30802431,  27.10262332,
#         26.96114892,  26.84358317,  26.42496503,  26.33823539,
#         26.25108738,  25.89849804,  25.78259682,  25.78259682,
#         25.78259682,  25.40409649,  25.40409649,  24.7610378 ,
#         24.7610378 ,  24.71458842,  24.52817585,  24.35960877,
#         23.96366686,  23.82147009,  23.6789084 ,  23.63131217,
#         23.41192526,  23.1823127 ,  23.1056411 ,  22.8656833 ,
#         22.8656833 ,  22.625294  ,  22.09563601,  21.24917305,
#         21.14371121,  20.79945564,  20.4189632 ,  20.18248667,
#         20.01295739,  19.14902287,  18.98452604,  18.74871813,
#         18.67661145,  18.4438083 ,  17.82122469,  17.77816642,
#         16.64502373,  16.48012713,  16.00869049,  15.81822597,
#         15.47167573,  15.05787226,  14.47643306,  13.99354041,
#         13.98390603,  13.7426456 ,  13.71707296,  13.43199543,
#         13.19254139,  13.14781867,  13.01968193,  12.91599832,
#         13.00333811,  13.10703562,  13.33637578,  14.10997074])

# %%
target
# Out:
# array([ 31. ,  29.5,  31. ,  32. ,  30. ,  31. ,  29. ,  31.5,  31.5,
#         37.7,  30.5,  28. ,  29.5,  29.5,  34.5,  30. ,  24.5,  28. ,
#         34.3,  36. ,  29. ,  29. ,  25. ,  23. ,  28. ,  26. ,  32.2,
#         32. ,  26. ,  19. ,  19. ,  32.4,  36. ,  25. ,  25. ,  29.9,
#         34. ,  21. ,  35. ,  29. ,  31.3,  33.5,  28. ,  32.9,  28. ,
#         32. ,  28. ,  28. ,  28. ,  25.1,  21.5,  27. ,  27. ,  21.6,
#         22. ,  22. ,  21. ,  22.3,  23.6,  32.7,  18. ,  23. ,  20.2,
#         19.8,  19.8,  38. ,  20.8,  15. ,  13. ,  18.1,  21.5,  19. ,
#         18. ,  19.1,  15. ,  20.5,  16. ,  18. ,  25.4,  19.2,  14. ,
#         15. ,  13. ,  16. ,  18.2,  15. ,  13. ,  17.5,  15. ,  15. ,
#         16. ,  14.5,  13. ,  14. ,  10. ,  13. ,  10. ,  16. ,  13. ,  12. ])
