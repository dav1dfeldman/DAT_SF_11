# %%
# Install seaborn
# If this line gives an error, go back to command prompt and run "conda install pip" and then try this step again
# !pip install seaborn
# Out:
# Requirement already satisfied (use --upgrade to upgrade): seaborn in /Users/David/anaconda/lib/python2.7/site-packages
# Cleaning up...

# %%
# Standard imports for data analysis packages in Python
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from IPython.display import Image

# This enables inline Plots
# %matplotlib inline

# Limit rows displayed in notebook
pd.set_option('display.max_rows', 20)
pd.set_option('display.precision', 3)

# %%
print 'Pandas Version: ', pd.__version__
print 'Numpy Version: ', np.__version__
# Out:
# Pandas Version:  0.14.1
# Numpy Version:  1.9.0

# %% [markdown]
# # Pandas DataFrame
#
# Think of DataFrame as a Table with Columns.  This is the workhorse of everything you will do with data analysis.  Learning Pandas and its functions can be challenging, but stick with it and ask questions.
#
# Who uses Pandas - Almost everyone who uses Python for Data Analysis - Netflix, Airbnb, Uber, Meetup.com to name a few.

# %% [markdown]
# Kaggle Titanic Dataset:
# =======================
#
# * Source: http://www.kaggle.com/c/titanic-gettingStarted/data

# %%
# Let's explore Titanic Dataset
titanic = pd.read_csv('http://biostat.mc.vanderbilt.edu/wiki/pub/Main/DataSets/titanic3.csv')

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 5          1         1                              Anderson, Mr. Harry
# 6          1         1                Andrews, Miss. Kornelia Theodosia
# 7          1         0                           Andrews, Mr. Thomas Jr
# 8          1         1    Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 9          1         0                          Artagaveytia, Mr. Ramon
# ...      ...       ...                                              ...
# 1299       3         0                              Yasbeck, Mr. Antoni
# 1300       3         1          Yasbeck, Mrs. Antoni (Selini Alexander)
# 1301       3         0                             Youseff, Mr. Gerious
# 1302       3         0                                Yousif, Mr. Wazli
# 1303       3         0                            Yousseff, Mr. Gerious
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex    age  sibsp  parch    ticket    fare    cabin embarked boat  \
# 0     female  29.00      0      0     24160  211.34       B5        S    2
# 1       male   0.92      1      2    113781  151.55  C22 C26        S   11
# 2     female   2.00      1      2    113781  151.55  C22 C26        S  NaN
# 3       male  30.00      1      2    113781  151.55  C22 C26        S  NaN
# 4     female  25.00      1      2    113781  151.55  C22 C26        S  NaN
# 5       male  48.00      0      0     19952   26.55      E12        S    3
# 6     female  63.00      1      0     13502   77.96       D7        S   10
# 7       male  39.00      0      0    112050    0.00      A36        S  NaN
# 8     female  53.00      2      0     11769   51.48     C101        S    D
# 9       male  71.00      0      0  PC 17609   49.50      NaN        C  NaN
# ...      ...    ...    ...    ...       ...     ...      ...      ...  ...
# 1299    male  27.00      1      0      2659   14.45      NaN        C    C
# 1300  female  15.00      1      0      2659   14.45      NaN        C  NaN
# 1301    male  45.50      0      0      2628    7.22      NaN        C  NaN
# 1302    male    NaN      0      0      2647    7.22      NaN        C  NaN
# 1303    male    NaN      0      0      2627   14.46      NaN        C  NaN
# 1304  female  14.50      1      0      2665   14.45      NaN        C  NaN
# 1305  female    NaN      1      0      2665   14.45      NaN        C  NaN
# 1306    male  26.50      0      0      2656    7.22      NaN        C  NaN
# 1307    male  27.00      0      0      2670    7.22      NaN        C  NaN
# 1308    male  29.00      0      0    315082    7.88      NaN        S  NaN
#
#       body                        home.dest
# 0      NaN                     St Louis, MO
# 1      NaN  Montreal, PQ / Chesterville, ON
# 2      NaN  Montreal, PQ / Chesterville, ON
# 3      135  Montreal, PQ / Chesterville, ON
# 4      NaN  Montreal, PQ / Chesterville, ON
# 5      NaN                     New York, NY
# 6      NaN                       Hudson, NY
# 7      NaN                      Belfast, NI
# 8      NaN              Bayside, Queens, NY
# 9       22              Montevideo, Uruguay
# ...    ...                              ...
# 1299   NaN                              NaN
# 1300   NaN                              NaN
# 1301   312                              NaN
# 1302   NaN                              NaN
# 1303   NaN                              NaN
# 1304   328                              NaN
# 1305   NaN                              NaN
# 1306   304                              NaN
# 1307   NaN                              NaN
# 1308   NaN                              NaN
#
# [1309 rows x 14 columns]

# %%
# Look at the Columns, data types, memory usage, null values
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
# pclass       1309 non-null int64
# survived     1309 non-null int64
# name         1309 non-null object
# sex          1309 non-null object
# age          1046 non-null float64
# sibsp        1309 non-null int64
# parch        1309 non-null int64
# ticket       1309 non-null object
# fare         1308 non-null float64
# cabin        295 non-null object
# embarked     1307 non-null object
# boat         486 non-null object
# body         121 non-null float64
# home.dest    745 non-null object
# dtypes: float64(3), int64(4), object(7)

# %%
# View Distribution
titanic.describe()
# Out:
#         pclass  survived      age    sibsp    parch     fare    body
# count  1309.00   1309.00  1046.00  1309.00  1309.00  1308.00  121.00
# mean      2.29      0.38    29.88     0.50     0.39    33.30  160.81
# std       0.84      0.49    14.41     1.04     0.87    51.76   97.70
# min       1.00      0.00     0.17     0.00     0.00     0.00    1.00
# 25%       2.00      0.00    21.00     0.00     0.00     7.90   72.00
# 50%       3.00      0.00    28.00     0.00     0.00    14.45  155.00
# 75%       3.00      1.00    39.00     1.00     0.00    31.27  256.00
# max       3.00      1.00    80.00     8.00     9.00   512.33  328.00

# %%
titanic.columns
# Out:
# Index([u'pclass', u'survived', u'name', u'sex', u'age', u'sibsp', u'parch', u'ticket', u'fare', u'cabin', u'embarked', u'boat', u'body', u'home.dest'], dtype='object')

# %%
titanic.rename(columns={'sex': 'gender'}, inplace = True)

# %%
titanic.head(2)
# Out:
#    pclass  survived                            name  gender    age  sibsp  \
# 0       1         1   Allen, Miss. Elisabeth Walton  female  29.00      0
# 1       1         1  Allison, Master. Hudson Trevor    male   0.92      1
#
#    parch  ticket    fare    cabin embarked boat  body  \
# 0      0   24160  211.34       B5        S    2   NaN
# 1      2  113781  151.55  C22 C26        S   11   NaN
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON

# %%
# So What is a Pandas Dataframe
# What is a Pandas DataFrame
Image(filename='images/dataframe.png')

# %% [markdown]
# ### Filter quickly

# %%
# show only that survived
titanic[titanic.gender == 'female'].head()
# Out:
#    pclass  survived                                             name  gender  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# 6       1         1                Andrews, Miss. Kornelia Theodosia  female
# 8       1         1    Appleton, Mrs. Edward Dale (Charlotte Lamson)  female
#
#    age  sibsp  parch  ticket    fare    cabin embarked boat  body  \
# 0   29      0      0   24160  211.34       B5        S    2   NaN
# 2    2      1      2  113781  151.55  C22 C26        S  NaN   NaN
# 4   25      1      2  113781  151.55  C22 C26        S  NaN   NaN
# 6   63      1      0   13502   77.96       D7        S   10   NaN
# 8   53      2      0   11769   51.48     C101        S    D   NaN
#
#                          home.dest  gender_val
# 0                     St Louis, MO           6
# 2  Montreal, PQ / Chesterville, ON           6
# 4  Montreal, PQ / Chesterville, ON           6
# 6                       Hudson, NY           6
# 8              Bayside, Queens, NY           6

# %%
# unique values
titanic['embarked'].unique()
# Out:
# array(['S', 'C', nan, 'Q'], dtype=object)

# %%
# How many Survived?
titanic.sex.value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-f1b0d801a125> in <module>()
#       1 # How many Survived?
# ----> 2 titanic.sex.value_counts()
#
# /Users/David/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    1841                 return self[name]
#    1842             raise AttributeError("'%s' object has no attribute '%s'" %
# -> 1843                                  (type(self).__name__, name))
#    1844
#    1845     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'sex'

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 0 to 1308
# Data columns (total 15 columns):
# pclass        1309 non-null int64
# survived      1309 non-null int64
# name          1309 non-null object
# gender        1309 non-null object
# age           1046 non-null float64
# sibsp         1309 non-null int64
# parch         1309 non-null int64
# ticket        1309 non-null object
# fare          1308 non-null float64
# cabin         295 non-null object
# embarked      1307 non-null object
# boat          486 non-null object
# body          121 non-null float64
# home.dest     745 non-null object
# gender_val    1309 non-null float64
# dtypes: float64(4), int64(4), object(7)

# %%
# Let's identify the missing age rows 
titanic[pd.isnull(titanic['age'])]
# Out:
#       pclass  survived                                               name  \
# 15         1         0                                Baumann, Mr. John D
# 37         1         1      Bradley, Mr. George ("George Arthur Brayton")
# 40         1         0                          Brewe, Dr. Arthur Jackson
# 46         1         0                              Cairns, Mr. Alexander
# 59         1         1  Cassebeer, Mrs. Henry Arthur Jr (Eleanor Genev...
# 69         1         1             Chibnall, Mrs. (Edith Martha Bowerman)
# 70         1         0              Chisholm, Mr. Roderick Robert Crispin
# 74         1         0                        Clifford, Mr. George Quincy
# 80         1         0                          Crafton, Mr. John Bertram
# 106        1         0                                 Farthing, Mr. John
# ...      ...       ...                                                ...
# 1282       3         0                                Ware, Mr. Frederick
# 1283       3         0                        Warren, Mr. Charles William
# 1284       3         0                                  Webber, Mr. James
# 1291       3         0                   Willer, Mr. Aaron ("Abi Weller")
# 1292       3         0                                 Willey, Mr. Edward
# 1293       3         0                  Williams, Mr. Howard Hugh "Harry"
# 1297       3         0                             Wiseman, Mr. Phillippe
# 1302       3         0                                  Yousif, Mr. Wazli
# 1303       3         0                              Yousseff, Mr. Gerious
# 1305       3         0                              Zabour, Miss. Thamine
#
#       gender  age  sibsp  parch            ticket    fare cabin embarked boat  \
# 15      male  NaN      0      0          PC 17318   25.93   NaN        S  NaN
# 37      male  NaN      0      0            111427   26.55   NaN        S    9
# 40      male  NaN      0      0            112379   39.60   NaN        C  NaN
# 46      male  NaN      0      0            113798   31.00   NaN        S  NaN
# 59    female  NaN      0      0             17770   27.72   NaN        C    5
# 69    female  NaN      0      1            113505   55.00   E33        S    6
# 70      male  NaN      0      0            112051    0.00   NaN        S  NaN
# 74      male  NaN      0      0            110465   52.00   A14        S  NaN
# 80      male  NaN      0      0            113791   26.55   NaN        S  NaN
# 106     male  NaN      0      0          PC 17483  221.78   C95        S  NaN
# ...      ...  ...    ...    ...               ...     ...   ...      ...  ...
# 1282    male  NaN      0      0            359309    8.05   NaN        S  NaN
# 1283    male  NaN      0      0        C.A. 49867    7.55   NaN        S  NaN
# 1284    male  NaN      0      0  SOTON/OQ 3101316    8.05   NaN        S  NaN
# 1291    male  NaN      0      0              3410    8.71   NaN        S  NaN
# 1292    male  NaN      0      0     S.O./P.P. 751    7.55   NaN        S  NaN
# 1293    male  NaN      0      0          A/5 2466    8.05   NaN        S  NaN
# 1297    male  NaN      0      0        A/4. 34244    7.25   NaN        S  NaN
# 1302    male  NaN      0      0              2647    7.22   NaN        C  NaN
# 1303    male  NaN      0      0              2627   14.46   NaN        C  NaN
# 1305  female  NaN      1      0              2665   14.45   NaN        C  NaN
#
#       body                         home.dest  gender_val
# 15     NaN                      New York, NY           5
# 37     NaN                   Los Angeles, CA           5
# 40     NaN                  Philadelphia, PA           5
# 46     NaN                               NaN           5
# 59     NaN                      New York, NY           6
# 69     NaN  St Leonards-on-Sea, England Ohio           6
# 70     NaN      Liverpool, England / Belfast           5
# 74     NaN                     Stoughton, MA           5
# 80     NaN                     Roachdale, IN           5
# 106    NaN                               NaN           5
# ...    ...                               ...         ...
# 1282   NaN                               NaN           5
# 1283   NaN                               NaN           5
# 1284   NaN                               NaN           5
# 1291   NaN                               NaN           5
# 1292   NaN                               NaN           5
# 1293   NaN                               NaN           5
# 1297   NaN                               NaN           5
# 1302   NaN                               NaN           5
# 1303   NaN                               NaN           5
# 1305   NaN                               NaN           6
#
# [263 rows x 15 columns]

# %%
titanic.age.mean()
# Out:
# 29.881137667304014

# %%
# Age - fix null values
titanic['age_imputed'] = titanic.age.fillna(titanic.age.mean())

# %%
titanic[pd.isnull(titanic.age)].head()
# Out:
#     pclass  survived                                               name  \
# 15       1         0                                Baumann, Mr. John D
# 37       1         1      Bradley, Mr. George ("George Arthur Brayton")
# 40       1         0                          Brewe, Dr. Arthur Jackson
# 46       1         0                              Cairns, Mr. Alexander
# 59       1         1  Cassebeer, Mrs. Henry Arthur Jr (Eleanor Genev...
#
#     gender  age  sibsp  parch    ticket   fare cabin embarked boat  body  \
# 15    male  NaN      0      0  PC 17318  25.93   NaN        S  NaN   NaN
# 37    male  NaN      0      0    111427  26.55   NaN        S    9   NaN
# 40    male  NaN      0      0    112379  39.60   NaN        C  NaN   NaN
# 46    male  NaN      0      0    113798  31.00   NaN        S  NaN   NaN
# 59  female  NaN      0      0     17770  27.72   NaN        C    5   NaN
#
#            home.dest  gender_val  age_imputed
# 15      New York, NY           5        29.88
# 37   Los Angeles, CA           5        29.88
# 40  Philadelphia, PA           5        29.88
# 46               NaN           5        29.88
# 59      New York, NY           6        29.88

# %%
# Did the inplace get us again?

# %%
titanic.sex.hist()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-b0f96347e6da> in <module>()
# ----> 1 titanic.sex.hist()
#
# /Users/David/anaconda/lib/python2.7/site-packages/pandas/tools/plotting.pyc in hist_series(self, by, ax, grid, xlabelsize, xrot, ylabelsize, yrot, figsize, bins, **kwds)
#    2570         values = self.dropna().values
#    2571
# -> 2572         ax.hist(values, bins=bins, **kwds)
#    2573         ax.grid(grid)
#    2574         axes = np.array([ax])
#
# /Users/David/anaconda/lib/python2.7/site-packages/matplotlib/axes/_axes.pyc in hist(self, x, bins, range, normed, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    5634             # this will automatically overwrite bins,
#    5635             # so that each histogram uses the same bins
# -> 5636             m, bins = np.histogram(x[i], bins, weights=w[i], **hist_kwargs)
#    5637             m = m.astype(float)  # causes problems later if it's an int
#    5638             if mlast is None:
#
# /Users/David/anaconda/lib/python2.7/site-packages/numpy/lib/function_base.pyc in histogram(a, bins, range, normed, weights, density)
#     186             else:
#     187                 range = (a.min(), a.max())
# --> 188         mn, mx = [mi + 0.0 for mi in range]
#     189         if mn == mx:
#     190             mn -= 0.5
#
# TypeError: cannot concatenate 'str' and 'float' objects

# %%
# Distribution of Age
titanic.age.hist(bins = 20)

# %%
# Distribution of Age by Gender
titanic.age.hist(by=titanic.gender);

# %%
# They look the same, buy see that y-axis is not the same
titanic.age.hist(by=titanic.pclass, sharey=True, bins = 10);

# %%
# Did your gender make a difference in survival
titanic.gender.value_counts()
# Out:
# male      843
# female    466
# dtype: int64

# %%
Image(filename='images/wesm_book_groupby.png')

# %%
titanic.columns
# Out:
# Index([u'pclass', u'survived', u'name', u'gender', u'age', u'sibsp', u'parch', u'ticket', u'fare', u'cabin', u'embarked', u'boat', u'body', u'home.dest', u'gender_val', u'age_imputed'], dtype='object')

# %%
titanic.pclass.hist(by=titanic.boat, sharey=True, bins = 3);
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-bcc8b966973d> in <module>()
# ----> 1 titanic.pclass.hist(by=titanic.boat, sharey=True, bins = 3);
#
# /Users/David/anaconda/lib/python2.7/site-packages/pandas/tools/plotting.pyc in hist_series(self, by, ax, grid, xlabelsize, xrot, ylabelsize, yrot, figsize, bins, **kwds)
#    2584         axes = grouped_hist(self, by=by, ax=ax, grid=grid, figsize=figsize, bins=bins,
#    2585                             xlabelsize=xlabelsize, xrot=xrot, ylabelsize=ylabelsize, yrot=yrot,
# -> 2586                             **kwds)
#    2587
#    2588     if axes.ndim == 1 and len(axes) == 1:
#
# /Users/David/anaconda/lib/python2.7/site-packages/pandas/tools/plotting.pyc in grouped_hist(data, column, by, ax, bins, figsize, layout, sharex, sharey, rot, grid, xlabelsize, xrot, ylabelsize, yrot, **kwargs)
#    2624     fig, axes = _grouped_plot(plot_group, data, column=column,
#    2625                               by=by, sharex=sharex, sharey=sharey,
# -> 2626                               figsize=figsize, layout=layout, rot=rot)
#    2627
#    2628     _set_ticks_props(axes, xlabelsize=xlabelsize, xrot=xrot,
#
# /Users/David/anaconda/lib/python2.7/site-packages/pandas/tools/plotting.pyc in _grouped_plot(plotf, data, column, by, numeric_only, figsize, sharex, sharey, layout, rot, ax, **kwargs)
#    2734         if numeric_only and isinstance(group, DataFrame):
#    2735             group = group._get_numeric_data()
# -> 2736         plotf(group, ax, **kwargs)
#    2737         ax.set_title(com.pprint_thing(key))
#    2738
#
# /Users/David/anaconda/lib/python2.7/site-packages/pandas/tools/plotting.pyc in plot_group(group, ax)
#    2618     """
#    2619     def plot_group(group, ax):
# -> 2620         ax.hist(group.dropna().values, bins=bins, **kwargs)
#    2621
#    2622     xrot = xrot or rot
#
# /Users/David/anaconda/lib/python2.7/site-packages/matplotlib/axes/_axes.pyc in hist(self, x, bins, range, normed, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    5556         elif len(flat) == 1 and not binsgiven:
#    5557             raise ValueError(
# -> 5558                 "x has only one data point. bins or range kwarg must be given")
#    5559
#    5560         # Massage 'x' for processing.
#
# ValueError: x has only one data point. bins or range kwarg must be given

# %%
titanic.groupby(['boat'])['pclass'].agg(['mean', 'median','count'])

# %%
# Groupby
titanic.groupby(['pclass', 'gender','survived'])['fare'].mean()
# Out:
# pclass  gender  survived
# 1       female  0           117.05
#                 1           109.14
#         male    0            68.44
#                 1            72.70
# 2       female  0            19.12
#                 1            23.76
#         male    0            19.86
#                 1            20.18
# 3       female  0            18.37
#                 1            12.17
#         male    0            12.13
#                 1            13.98
# Name: fare, dtype: float64

# %%
# Groupby
titanic.groupby(['pclass', 'gender'])['survived'].agg(['mean', 'count'])
# Out:
#                mean  count
# pclass gender
# 1      female  0.97    144
#        male    0.34    179
# 2      female  0.89    106
#        male    0.15    171
# 3      female  0.49    216
#        male    0.15    493

# %%
# Show how many survivied by gender and class
class_gender_group = titanic.groupby(['pclass', 'gender'])

# %%
# group not visible by itself
class_gender_group

# %%
for k, group in class_gender_group:
    print(k)
# Out:
# (1, 'female')
# (1, 'male')
# (2, 'female')
# (2, 'male')
# (3, 'female')
# (3, 'male')

# %%
# don't use but interesting
for k, group in class_gender_group:
    print group
# Out:
#      pclass  survived                                               name  \
# 0         1         1                      Allen, Miss. Elisabeth Walton
# 2         1         0                       Allison, Miss. Helen Loraine
# 4         1         0    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 6         1         1                  Andrews, Miss. Kornelia Theodosia
# 8         1         1      Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 11        1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# 12        1         1                      Aubart, Mme. Leontine Pauline
# 13        1         1                       Barber, Miss. Ellen "Nellie"
# 17        1         1    Baxter, Mrs. James (Helene DeLaudeniere Chaput)
# 18        1         1                              Bazzani, Miss. Albina
# ..      ...       ...                                                ...
# 297       1         1                     Thorne, Mrs. Gertrude Maybelle
# 302       1         1                                   Ward, Miss. Anna
# 304       1         1   Warren, Mrs. Frank Manley (Anna Sophia Atkinson)
# 308       1         1              White, Mrs. John Stuart (Ella Holmes)
# 309       1         1                           Wick, Miss. Mary Natalie
# 311       1         1         Wick, Mrs. George Dennick (Mary Hitchcock)
# 314       1         1       Widener, Mrs. George Dunton (Eleanor Elkins)
# 315       1         1                           Willard, Miss. Constance
# 319       1         1                          Wilson, Miss. Helen Alice
# 322       1         1                           Young, Miss. Marie Grice
#
#      gender  age  sibsp  parch    ticket    fare    cabin embarked  boat  \
# 0    female   29      0      0     24160  211.34       B5        S     2
# 2    female    2      1      2    113781  151.55  C22 C26        S   NaN
# 4    female   25      1      2    113781  151.55  C22 C26        S   NaN
# 6    female   63      1      0     13502   77.96       D7        S    10
# 8    female   53      2      0     11769   51.48     C101        S     D
# 11   female   18      1      0  PC 17757  227.53  C62 C64        C     4
# 12   female   24      0      0  PC 17477   69.30      B35        C     9
# 13   female   26      0      0     19877   78.85      NaN        S     6
# 17   female   50      0      1  PC 17558  247.52  B58 B60        C     6
# 18   female   32      0      0     11813   76.29      D15        C     8
# ..      ...  ...    ...    ...       ...     ...      ...      ...   ...
# 297  female  NaN      0      0  PC 17585   79.20      NaN        C     D
# 302  female   35      0      0  PC 17755  512.33      NaN        C     3
# 304  female   60      1      0    110813   75.25      D37        C     5
# 308  female   55      0      0  PC 17760  135.63      C32        C     8
# 309  female   31      0      2     36928  164.87       C7        S     8
# 311  female   45      1      1     36928  164.87      NaN        S     8
# 314  female   50      1      1    113503  211.50      C80        C     4
# 315  female   21      0      0    113795   26.55      NaN        S  8 10
# 319  female   31      0      0     16966  134.50  E39 E41        C     3
# 322  female   36      0      0  PC 17760  135.63      C32        C     8
#
#      body                           home.dest  gender_val  age_imputed
# 0     NaN                        St Louis, MO           6        29.00
# 2     NaN     Montreal, PQ / Chesterville, ON           6         2.00
# 4     NaN     Montreal, PQ / Chesterville, ON           6        25.00
# 6     NaN                          Hudson, NY           6        63.00
# 8     NaN                 Bayside, Queens, NY           6        53.00
# 11    NaN                        New York, NY           6        18.00
# 12    NaN                       Paris, France           6        24.00
# 13    NaN                                 NaN           6        26.00
# 17    NaN                        Montreal, PQ           6        50.00
# 18    NaN                                 NaN           6        32.00
# ..    ...                                 ...         ...          ...
# 297   NaN                        New York, NY           6        29.88
# 302   NaN                                 NaN           6        35.00
# 304   NaN                        Portland, OR           6        60.00
# 308   NaN  New York, NY / Briarcliff Manor NY           6        55.00
# 309   NaN                      Youngstown, OH           6        31.00
# 311   NaN                      Youngstown, OH           6        45.00
# 314   NaN                     Elkins Park, PA           6        50.00
# 315   NaN                          Duluth, MN           6        21.00
# 319   NaN                                 NaN           6        31.00
# 322   NaN       New York, NY / Washington, DC           6        36.00
#
# [144 rows x 16 columns]
#      pclass  survived                                    name gender    age  \
# 1         1         1          Allison, Master. Hudson Trevor   male   0.92
# 3         1         0    Allison, Mr. Hudson Joshua Creighton   male  30.00
# 5         1         1                     Anderson, Mr. Harry   male  48.00
# 7         1         0                  Andrews, Mr. Thomas Jr   male  39.00
# 9         1         0                 Artagaveytia, Mr. Ramon   male  71.00
# 10        1         0                  Astor, Col. John Jacob   male  47.00
# 14        1         1    Barkworth, Mr. Algernon Henry Wilson   male  80.00
# 15        1         0                     Baumann, Mr. John D   male    NaN
# 16        1         0                Baxter, Mr. Quigg Edmond   male  24.00
# 19        1         0                    Beattie, Mr. Thomson   male  36.00
# ..      ...       ...                                     ...    ...    ...
# 306       1         0             White, Mr. Percival Wayland   male  54.00
# 307       1         0               White, Mr. Richard Frasar   male  21.00
# 310       1         0                Wick, Mr. George Dennick   male  57.00
# 312       1         0              Widener, Mr. George Dunton   male  50.00
# 313       1         0               Widener, Mr. Harry Elkins   male  27.00
# 316       1         0             Williams, Mr. Charles Duane   male  51.00
# 317       1         1         Williams, Mr. Richard Norris II   male  21.00
# 318       1         0  Williams-Lambert, Mr. Fletcher Fellows   male    NaN
# 320       1         1                       Woolner, Mr. Hugh   male    NaN
# 321       1         0                      Wright, Mr. George   male  62.00
#
#      sibsp  parch    ticket    fare    cabin embarked boat  body  \
# 1        1      2    113781  151.55  C22 C26        S   11   NaN
# 3        1      2    113781  151.55  C22 C26        S  NaN   135
# 5        0      0     19952   26.55      E12        S    3   NaN
# 7        0      0    112050    0.00      A36        S  NaN   NaN
# 9        0      0  PC 17609   49.50      NaN        C  NaN    22
# 10       1      0  PC 17757  227.53  C62 C64        C  NaN   124
# 14       0      0     27042   30.00      A23        S    B   NaN
# 15       0      0  PC 17318   25.93      NaN        S  NaN   NaN
# 16       0      1  PC 17558  247.52  B58 B60        C  NaN   NaN
# 19       0      0     13050   75.24       C6        C    A   NaN
# ..     ...    ...       ...     ...      ...      ...  ...   ...
# 306      0      1     35281   77.29      D26        S  NaN   NaN
# 307      0      1     35281   77.29      D26        S  NaN   169
# 310      1      1     36928  164.87      NaN        S  NaN   NaN
# 312      1      1    113503  211.50      C80        C  NaN   NaN
# 313      0      2    113503  211.50      C82        C  NaN   NaN
# 316      0      1  PC 17597   61.38      NaN        C  NaN   NaN
# 317      0      1  PC 17597   61.38      NaN        C    A   NaN
# 318      0      0    113510   35.00     C128        S  NaN   NaN
# 320      0      0     19947   35.50      C52        S    D   NaN
# 321      0      0    113807   26.55      NaN        S  NaN   NaN
#
#                             home.dest  gender_val  age_imputed
# 1     Montreal, PQ / Chesterville, ON           5         0.92
# 3     Montreal, PQ / Chesterville, ON           5        30.00
# 5                        New York, NY           5        48.00
# 7                         Belfast, NI           5        39.00
# 9                 Montevideo, Uruguay           5        71.00
# 10                       New York, NY           5        47.00
# 14                      Hessle, Yorks           5        80.00
# 15                       New York, NY           5        29.88
# 16                       Montreal, PQ           5        24.00
# 19                       Winnipeg, MN           5        36.00
# ..                                ...         ...          ...
# 306                     Brunswick, ME           5        54.00
# 307                     Brunswick, ME           5        21.00
# 310                    Youngstown, OH           5        57.00
# 312                   Elkins Park, PA           5        50.00
# 313                   Elkins Park, PA           5        27.00
# 316  Geneva, Switzerland / Radnor, PA           5        51.00
# 317  Geneva, Switzerland / Radnor, PA           5        21.00
# 318                   London, England           5        29.88
# 320                   London, England           5        29.88
# 321                       Halifax, NS           5        62.00
#
# [179 rows x 16 columns]
#      pclass  survived                                               name  \
# 324       2         1              Abelson, Mrs. Samuel (Hannah Wizosky)
# 329       2         1  Angle, Mrs. William A (Florence "Mary" Agnes H...
# 333       2         1                            Ball, Mrs. (Ada E Hall)
# 337       2         1                  Beane, Mrs. Edward (Ethel Clarke)
# 340       2         1                        Becker, Miss. Marion Louise
# 341       2         1                       Becker, Miss. Ruth Elizabeth
# 342       2         1   Becker, Mrs. Allen Oliver (Nellie E Baumgardner)
# 344       2         1                            Bentham, Miss. Lilian W
# 349       2         1                      Brown, Miss. Amelia "Mildred"
# 350       2         1                          Brown, Miss. Edith Eileen
# ..      ...       ...                                                ...
# 583       2         1  Watt, Mrs. James (Elizabeth "Bessie" Inglis Mi...
# 584       2         1                                Webber, Miss. Susan
# 586       2         1      Weisz, Mrs. Leopold (Mathilde Francoise Pede)
# 588       2         1                                  Wells, Miss. Joan
# 589       2         1  Wells, Mrs. Arthur Henry ("Addie" Dart Trevaskis)
# 590       2         1                              West, Miss. Barbara J
# 591       2         1                       West, Miss. Constance Mirium
# 593       2         1            West, Mrs. Edwy Arthur (Ada Mary Worth)
# 598       2         1                               Wright, Miss. Marion
# 599       2         0             Yrois, Miss. Henriette ("Mrs Harbeck")
#
#      gender    age  sibsp  parch      ticket   fare cabin embarked boat  body  \
# 324  female  28.00      1      0   P/PP 3381  24.00   NaN        C   10   NaN
# 329  female  36.00      1      0      226875  26.00   NaN        S   11   NaN
# 333  female  36.00      0      0       28551  13.00     D        S   10   NaN
# 337  female  19.00      1      0        2908  26.00   NaN        S   13   NaN
# 340  female   4.00      2      1      230136  39.00    F4        S   11   NaN
# 341  female  12.00      2      1      230136  39.00    F4        S   13   NaN
# 342  female  36.00      0      3      230136  39.00    F4        S   11   NaN
# 344  female  19.00      0      0       28404  13.00   NaN        S   12   NaN
# 349  female  24.00      0      0      248733  13.00   F33        S   11   NaN
# 350  female  15.00      0      2       29750  39.00   NaN        S   14   NaN
# ..      ...    ...    ...    ...         ...    ...   ...      ...  ...   ...
# 583  female  40.00      0      0  C.A. 33595  15.75   NaN        S    9   NaN
# 584  female  32.50      0      0       27267  13.00  E101        S   12   NaN
# 586  female  29.00      1      0      228414  26.00   NaN        S   10   NaN
# 588  female   4.00      1      1       29103  23.00   NaN        S   14   NaN
# 589  female  29.00      0      2       29103  23.00   NaN        S   14   NaN
# 590  female   0.92      1      2  C.A. 34651  27.75   NaN        S   10   NaN
# 591  female   5.00      1      2  C.A. 34651  27.75   NaN        S   10   NaN
# 593  female  33.00      1      2  C.A. 34651  27.75   NaN        S   10   NaN
# 598  female  26.00      0      0      220844  13.50   NaN        S    9   NaN
# 599  female  24.00      0      0      248747  13.00   NaN        S  NaN   NaN
#
#                                  home.dest  gender_val  age_imputed
# 324                    Russia New York, NY           6        28.00
# 329                       Warwick, England           6        36.00
# 333       Bristol, Avon / Jacksonville, FL           6        36.00
# 337                 Norwich / New York, NY           6        19.00
# 340     Guntur, India / Benton Harbour, MI           6         4.00
# 341     Guntur, India / Benton Harbour, MI           6        12.00
# 342     Guntur, India / Benton Harbour, MI           6        36.00
# 344                          Rochester, NY           6        19.00
# 349                  London / Montreal, PQ           6        24.00
# 350  Cape Town, South Africa / Seattle, WA           6        15.00
# ..                                     ...         ...          ...
# 583                Aberdeen / Portland, OR           6        40.00
# 584                 England / Hartford, CT           6        32.50
# 586     Bromsgrove, England / Montreal, PQ           6        29.00
# 588                   Cornwall / Akron, OH           6         4.00
# 589                   Cornwall / Akron, OH           6        29.00
# 590                    Bournmouth, England           6         0.92
# 591                    Bournmouth, England           6         5.00
# 593                    Bournmouth, England           6        33.00
# 598    Yoevil, England / Cottage Grove, OR           6        26.00
# 599                                  Paris           6        24.00
#
# [106 rows x 16 columns]
#      pclass  survived                            name gender  age  sibsp  \
# 323       2         0             Abelson, Mr. Samuel   male   30      1
# 325       2         0  Aldworth, Mr. Charles Augustus   male   30      0
# 326       2         0      Andrew, Mr. Edgardo Samuel   male   18      0
# 327       2         0        Andrew, Mr. Frank Thomas   male   25      0
# 328       2         0            Angle, Mr. William A   male   34      1
# 330       2         0                 Ashby, Mr. John   male   57      0
# 331       2         0        Bailey, Mr. Percy Andrew   male   18      0
# 332       2         0  Baimbrigge, Mr. Charles Robert   male   23      0
# 334       2         0   Banfield, Mr. Frederick James   male   28      0
# 335       2         0      Bateman, Rev. Robert James   male   51      0
# ..      ...       ...                             ...    ...  ...    ...
# 578       2         0            Ware, Mr. John James   male   30      1
# 579       2         0       Ware, Mr. William Jeffery   male   23      1
# 581       2         0      Watson, Mr. Ennis Hastings   male  NaN      0
# 585       2         0              Weisz, Mr. Leopold   male   27      1
# 587       2         1     Wells, Master. Ralph Lester   male    2      1
# 592       2         0           West, Mr. Edwy Arthur   male   36      1
# 594       2         0           Wheadon, Mr. Edward H   male   66      0
# 595       2         0  Wheeler, Mr. Edwin "Frederick"   male  NaN      0
# 596       2         1           Wilhelms, Mr. Charles   male   31      0
# 597       2         1    Williams, Mr. Charles Eugene   male  NaN      0
#
#      parch            ticket   fare cabin embarked boat  body  \
# 323      0         P/PP 3381  24.00   NaN        C  NaN   NaN
# 325      0            248744  13.00   NaN        S  NaN   NaN
# 326      0            231945  11.50   NaN        S  NaN   NaN
# 327      0        C.A. 34050  10.50   NaN        S  NaN   NaN
# 328      0            226875  26.00   NaN        S  NaN   NaN
# 330      0            244346  13.00   NaN        S  NaN   NaN
# 331      0             29108  11.50   NaN        S  NaN   NaN
# 332      0        C.A. 31030  10.50   NaN        S  NaN   NaN
# 334      0  C.A./SOTON 34068  10.50   NaN        S  NaN   NaN
# 335      0       S.O.P. 1166  12.53   NaN        S  NaN   174
# ..     ...               ...    ...   ...      ...  ...   ...
# 578      0          CA 31352  21.00   NaN        S  NaN   NaN
# 579      0             28666  10.50   NaN        S  NaN   NaN
# 581      0            239856   0.00   NaN        S  NaN   NaN
# 585      0            228414  26.00   NaN        S  NaN   293
# 587      1             29103  23.00   NaN        S   14   NaN
# 592      2        C.A. 34651  27.75   NaN        S  NaN   NaN
# 594      0        C.A. 24579  10.50   NaN        S  NaN   NaN
# 595      0     SC/PARIS 2159  12.88   NaN        S  NaN   NaN
# 596      0            244270  13.00   NaN        S    9   NaN
# 597      0            244373  13.00   NaN        S   14   NaN
#
#                                     home.dest  gender_val  age_imputed
# 323                       Russia New York, NY           5        30.00
# 325                        Bryn Mawr, PA, USA           5        30.00
# 326  Buenos Aires, Argentina / New Jersey, NJ           5        18.00
# 327            Cornwall, England Houghton, MI           5        25.00
# 328                          Warwick, England           5        34.00
# 330                          West Hoboken, NJ           5        57.00
# 331            Penzance, Cornwall / Akron, OH           5        18.00
# 332                                  Guernsey           5        23.00
# 334           Plymouth, Dorset / Houghton, MI           5        28.00
# 335                          Jacksonville, FL           5        51.00
# ..                                        ...         ...          ...
# 578        Bristol, England / New Britain, CT           5        30.00
# 579                                       NaN           5        23.00
# 581                                   Belfast           5        29.88
# 585        Bromsgrove, England / Montreal, PQ           5        27.00
# 587                      Cornwall / Akron, OH           5         2.00
# 592                       Bournmouth, England           5        36.00
# 594          Guernsey, England / Edgewood, RI           5        66.00
# 595                                       NaN           5        29.88
# 596                           London, England           5        31.00
# 597                           Harrow, England           5        29.88
#
# [171 rows x 16 columns]
#       pclass  survived                                               name  \
# 603        3         1                   Abbott, Mrs. Stanton (Rosa Hunt)
# 604        3         1                        Abelseth, Miss. Karen Marie
# 607        3         1          Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 610        3         0     Ahlin, Mrs. Johan (Johanna Persdotter Larsson)
# 612        3         1                         Aks, Mrs. Sam (Leah Rosen)
# 621        3         1    Andersen-Jensen, Miss. Carla Christine Nielsine
# 623        3         0                 Andersson, Miss. Ebba Iris Alfrida
# 624        3         0                  Andersson, Miss. Ellis Anna Maria
# 625        3         1                    Andersson, Miss. Erna Alexandra
# 626        3         0             Andersson, Miss. Ida Augusta Margareta
# ...      ...       ...                                                ...
# 1265       3         0                          Van Impe, Miss. Catharina
# 1267       3         0  Van Impe, Mrs. Jean Baptiste (Rosalie Paula Go...
# 1273       3         0                 Vander Planke, Miss. Augusta Maria
# 1276       3         0  Vander Planke, Mrs. Julius (Emelia Maria Vande...
# 1279       3         0               Vestrom, Miss. Hulda Amanda Adolfina
# 1286       3         1    Whabee, Mrs. George Joseph (Shawneene Abi-Saab)
# 1290       3         1                   Wilkes, Mrs. James (Ellen Needs)
# 1300       3         1            Yasbeck, Mrs. Antoni (Selini Alexander)
# 1304       3         0                               Zabour, Miss. Hileni
# 1305       3         0                              Zabour, Miss. Thamine
#
#       gender   age  sibsp  parch     ticket   fare cabin embarked boat  body  \
# 603   female  35.0      1      1  C.A. 2673  20.25   NaN        S    A   NaN
# 604   female  16.0      0      0     348125   7.65   NaN        S   16   NaN
# 607   female  18.0      0      0       2657   7.23   NaN        C    C   NaN
# 610   female  40.0      1      0       7546   9.47   NaN        S  NaN   NaN
# 612   female  18.0      0      1     392091   9.35   NaN        S   13   NaN
# 621   female  19.0      1      0     350046   7.85   NaN        S   16   NaN
# 623   female   6.0      4      2     347082  31.27   NaN        S  NaN   NaN
# 624   female   2.0      4      2     347082  31.27   NaN        S  NaN   NaN
# 625   female  17.0      4      2    3101281   7.92   NaN        S    D   NaN
# 626   female  38.0      4      2     347091   7.78   NaN        S  NaN   NaN
# ...      ...   ...    ...    ...        ...    ...   ...      ...  ...   ...
# 1265  female  10.0      0      2     345773  24.15   NaN        S  NaN   NaN
# 1267  female  30.0      1      1     345773  24.15   NaN        S  NaN   NaN
# 1273  female  18.0      2      0     345764  18.00   NaN        S  NaN   NaN
# 1276  female  31.0      1      0     345763  18.00   NaN        S  NaN   NaN
# 1279  female  14.0      0      0     350406   7.85   NaN        S  NaN   NaN
# 1286  female  38.0      0      0       2688   7.23   NaN        C    C   NaN
# 1290  female  47.0      1      0     363272   7.00   NaN        S  NaN   NaN
# 1300  female  15.0      1      0       2659  14.45   NaN        C  NaN   NaN
# 1304  female  14.5      1      0       2665  14.45   NaN        C  NaN   328
# 1305  female   NaN      1      0       2665  14.45   NaN        C  NaN   NaN
#
#                                  home.dest  gender_val  age_imputed
# 603                    East Providence, RI           6        35.00
# 604                 Norway Los Angeles, CA           6        16.00
# 607                         Greensburg, PA           6        18.00
# 610                      Sweden Akeley, MN           6        40.00
# 612            London, England Norfolk, VA           6        18.00
# 621                                    NaN           6        19.00
# 623                    Sweden Winnipeg, MN           6         6.00
# 624                    Sweden Winnipeg, MN           6         2.00
# 625   Ruotsinphyhtaa, Finland New York, NY           6        17.00
# 626           Vadsbro, Sweden Ministee, MI           6        38.00
# ...                                    ...         ...          ...
# 1265                                   NaN           6        10.00
# 1267                                   NaN           6        30.00
# 1273                                   NaN           6        18.00
# 1276                                   NaN           6        31.00
# 1279                                   NaN           6        14.00
# 1286                                   NaN           6        38.00
# 1290                                   NaN           6        47.00
# 1300                                   NaN           6        15.00
# 1304                                   NaN           6        14.50
# 1305                                   NaN           6        29.88
#
# [216 rows x 16 columns]
#       pclass  survived                                      name gender  \
# 600        3         0                       Abbing, Mr. Anthony   male
# 601        3         0             Abbott, Master. Eugene Joseph   male
# 602        3         0               Abbott, Mr. Rossmore Edward   male
# 605        3         1             Abelseth, Mr. Olaus Jorgensen   male
# 606        3         1  Abrahamsson, Mr. Abraham August Johannes   male
# 608        3         0            Adahl, Mr. Mauritz Nils Martin   male
# 609        3         0                           Adams, Mr. John   male
# 611        3         1                 Aks, Master. Philip Frank   male
# 613        3         1               Albimona, Mr. Nassef Cassem   male
# 614        3         0                    Alexander, Mr. William   male
# ...      ...       ...                                       ...    ...
# 1296       3         0                          Wirz, Mr. Albert   male
# 1297       3         0                    Wiseman, Mr. Phillippe   male
# 1298       3         0                 Wittevrongel, Mr. Camille   male
# 1299       3         0                       Yasbeck, Mr. Antoni   male
# 1301       3         0                      Youseff, Mr. Gerious   male
# 1302       3         0                         Yousif, Mr. Wazli   male
# 1303       3         0                     Yousseff, Mr. Gerious   male
# 1306       3         0                 Zakarian, Mr. Mapriededer   male
# 1307       3         0                       Zakarian, Mr. Ortin   male
# 1308       3         0                        Zimmerman, Mr. Leo   male
#
#         age  sibsp  parch            ticket   fare  cabin embarked boat  body  \
# 600   42.00      0      0         C.A. 5547   7.55    NaN        S  NaN   NaN
# 601   13.00      0      2         C.A. 2673  20.25    NaN        S  NaN   NaN
# 602   16.00      1      1         C.A. 2673  20.25    NaN        S  NaN   190
# 605   25.00      0      0            348122   7.65  F G63        S    A   NaN
# 606   20.00      0      0  SOTON/O2 3101284   7.92    NaN        S   15   NaN
# 608   30.00      0      0            C 7076   7.25    NaN        S  NaN    72
# 609   26.00      0      0            341826   8.05    NaN        S  NaN   103
# 611    0.83      0      1            392091   9.35    NaN        S   11   NaN
# 613   26.00      0      0              2699  18.79    NaN        C   15   NaN
# 614   26.00      0      0              3474   7.89    NaN        S  NaN   NaN
# ...     ...    ...    ...               ...    ...    ...      ...  ...   ...
# 1296  27.00      0      0            315154   8.66    NaN        S  NaN   131
# 1297    NaN      0      0        A/4. 34244   7.25    NaN        S  NaN   NaN
# 1298  36.00      0      0            345771   9.50    NaN        S  NaN   NaN
# 1299  27.00      1      0              2659  14.45    NaN        C    C   NaN
# 1301  45.50      0      0              2628   7.22    NaN        C  NaN   312
# 1302    NaN      0      0              2647   7.22    NaN        C  NaN   NaN
# 1303    NaN      0      0              2627  14.46    NaN        C  NaN   NaN
# 1306  26.50      0      0              2656   7.22    NaN        C  NaN   304
# 1307  27.00      0      0              2670   7.22    NaN        C  NaN   NaN
# 1308  29.00      0      0            315082   7.88    NaN        S  NaN   NaN
#
#                               home.dest  gender_val  age_imputed
# 600                                 NaN           5        42.00
# 601                 East Providence, RI           5        13.00
# 602                 East Providence, RI           5        16.00
# 605                  Perkins County, SD           5        25.00
# 606   Taalintehdas, Finland Hoboken, NJ           5        20.00
# 608         Asarum, Sweden Brooklyn, NY           5        30.00
# 609                Bournemouth, England           5        26.00
# 611         London, England Norfolk, VA           5         0.83
# 613            Syria Fredericksburg, VA           5        26.00
# 614                  England Albion, NY           5        26.00
# ...                                 ...         ...          ...
# 1296                                NaN           5        27.00
# 1297                                NaN           5        29.88
# 1298                                NaN           5        36.00
# 1299                                NaN           5        27.00
# 1301                                NaN           5        45.50
# 1302                                NaN           5        29.88
# 1303                                NaN           5        29.88
# 1306                                NaN           5        26.50
# 1307                                NaN           5        27.00
# 1308                                NaN           5        29.00
#
# [493 rows x 16 columns]

# %%
sns.FacetGrid(titanic, row='gender', col='pclass')

# %%
# Plot how many survived, by gender and class
grid_plot = sns.FacetGrid(titanic, row='gender', col='pclass')
grid_plot.map(sns.regplot, 'survived', 'age',color='.3', fit_reg=False, x_jitter=.25)

# %%
titanic.boxplot(['age'], by = 'pclass');

# %%
ax = sns.boxplot(titanic.age, groupby=titanic.pclass)
ax.set_title('Age Distribution by class')

# %%
# Who paid the highest Fare in Titanic.  Did they survive?
titanic.sort_index(by='fare', ascending=False)
# Out:
#       pclass  survived                                               name  \
# 183        1         1                             Lesurer, Mr. Gustave J
# 302        1         1                                   Ward, Miss. Anna
# 49         1         1                 Cardeza, Mr. Thomas Drake Martinez
# 50         1         1  Cardeza, Mrs. James Warburton Martinez (Charlo...
# 113        1         1                         Fortune, Miss. Mabel Helen
# 114        1         0                     Fortune, Mr. Charles Alexander
# 115        1         0                                  Fortune, Mr. Mark
# 116        1         1                Fortune, Mrs. Mark (Mary McDougald)
# 111        1         1                     Fortune, Miss. Alice Elizabeth
# 112        1         1                         Fortune, Miss. Ethel Flora
# ...      ...       ...                                                ...
# 150        1         0                              Harrison, Mr. William
# 528        2         0                        Parkes, Mr. Francis "Frank"
# 896        3         0                                Johnson, Mr. Alfred
# 223        1         0                      Parr, Mr. William Henry Marsh
# 234        1         0                    Reuchlin, Jonkheer. John George
# 363        2         0                              Campbell, Mr. William
# 384        2         0                     Cunningham, Mr. Alfred Fleming
# 581        2         0                         Watson, Mr. Ennis Hastings
# 410        2         0                   Frost, Mr. Anthony Wood "Archie"
# 1225       3         0                                 Storey, Mr. Thomas
#
#       gender   age  sibsp  parch    ticket    fare        cabin embarked boat  \
# 183     male  35.0      0      0  PC 17755  512.33         B101        C    3
# 302   female  35.0      0      0  PC 17755  512.33          NaN        C    3
# 49      male  36.0      0      1  PC 17755  512.33  B51 B53 B55        C    3
# 50    female  58.0      0      1  PC 17755  512.33  B51 B53 B55        C    3
# 113   female  23.0      3      2     19950  263.00  C23 C25 C27        S   10
# 114     male  19.0      3      2     19950  263.00  C23 C25 C27        S  NaN
# 115     male  64.0      1      4     19950  263.00  C23 C25 C27        S  NaN
# 116   female  60.0      1      4     19950  263.00  C23 C25 C27        S   10
# 111   female  24.0      3      2     19950  263.00  C23 C25 C27        S   10
# 112   female  28.0      3      2     19950  263.00  C23 C25 C27        S   10
# ...      ...   ...    ...    ...       ...     ...          ...      ...  ...
# 150     male  40.0      0      0    112059    0.00          B94        S  NaN
# 528     male   NaN      0      0    239853    0.00          NaN        S  NaN
# 896     male  49.0      0      0      LINE    0.00          NaN        S  NaN
# 223     male   NaN      0      0    112052    0.00          NaN        S  NaN
# 234     male  38.0      0      0     19972    0.00          NaN        S  NaN
# 363     male   NaN      0      0    239853    0.00          NaN        S  NaN
# 384     male   NaN      0      0    239853    0.00          NaN        S  NaN
# 581     male   NaN      0      0    239856    0.00          NaN        S  NaN
# 410     male   NaN      0      0    239854    0.00          NaN        S  NaN
# 1225    male  60.5      0      0      3701     NaN          NaN        S  NaN
#
#       body                                       home.dest  gender_val  \
# 183    NaN                                             NaN           5
# 302    NaN                                             NaN           6
# 49     NaN  Austria-Hungary / Germantown, Philadelphia, PA           5
# 50     NaN                    Germantown, Philadelphia, PA           6
# 113    NaN                                    Winnipeg, MB           6
# 114    NaN                                    Winnipeg, MB           5
# 115    NaN                                    Winnipeg, MB           5
# 116    NaN                                    Winnipeg, MB           6
# 111    NaN                                    Winnipeg, MB           6
# 112    NaN                                    Winnipeg, MB           6
# ...    ...                                             ...         ...
# 150    110                                             NaN           5
# 528    NaN                                         Belfast           5
# 896    NaN                                             NaN           5
# 223    NaN                                         Belfast           5
# 234    NaN                          Rotterdam, Netherlands           5
# 363    NaN                                         Belfast           5
# 384    NaN                                         Belfast           5
# 581    NaN                                         Belfast           5
# 410    NaN                                         Belfast           5
# 1225   261                                             NaN           5
#
#       age_imputed
# 183         35.00
# 302         35.00
# 49          36.00
# 50          58.00
# 113         23.00
# 114         19.00
# 115         64.00
# 116         60.00
# 111         24.00
# 112         28.00
# ...           ...
# 150         40.00
# 528         29.88
# 896         49.00
# 223         29.88
# 234         38.00
# 363         29.88
# 384         29.88
# 581         29.88
# 410         29.88
# 1225        60.50
#
# [1309 rows x 16 columns]

# %%
# Custom Translation of Values and creating new Columns
# %time
def gender_map(val):
    if val == 'male':
        return 1
    return 0
titanic['gender_val'] = titanic.gender.map(gender_map)
# Out:
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 6.91 µs

# %%
titanic.head()
# Out:
#    pclass  survived                                             name  gender  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#      age  sibsp  parch  ticket    fare    cabin embarked boat  body  \
# 0  29.00      0      0   24160  211.34       B5        S    2   NaN
# 1   0.92      1      2  113781  151.55  C22 C26        S   11   NaN
# 2   2.00      1      2  113781  151.55  C22 C26        S  NaN   NaN
# 3  30.00      1      2  113781  151.55  C22 C26        S  NaN   135
# 4  25.00      1      2  113781  151.55  C22 C26        S  NaN   NaN
#
#                          home.dest  gender_val  age_imputed
# 0                     St Louis, MO           0        29.00
# 1  Montreal, PQ / Chesterville, ON           1         0.92
# 2  Montreal, PQ / Chesterville, ON           0         2.00
# 3  Montreal, PQ / Chesterville, ON           1        30.00
# 4  Montreal, PQ / Chesterville, ON           0        25.00

# %%
# Some mistakes I made when learning to work with Pandas
# Don't use Loop to update Dataframe
# %time
for k, row in titanic.iterrows():
    if row.gender == 'male':
        titanic.ix[k, 'gender_val'] = 5
    else:
        titanic.ix[k, 'gender_val'] = 6
# Out:
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 8.11 µs

# %%
titanic.head()
# Out:
#    pclass  survived                                             name  gender  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#      age  sibsp  parch  ticket    fare    cabin embarked boat  body  \
# 0  29.00      0      0   24160  211.34       B5        S    2   NaN
# 1   0.92      1      2  113781  151.55  C22 C26        S   11   NaN
# 2   2.00      1      2  113781  151.55  C22 C26        S  NaN   NaN
# 3  30.00      1      2  113781  151.55  C22 C26        S  NaN   135
# 4  25.00      1      2  113781  151.55  C22 C26        S  NaN   NaN
#
#                          home.dest  gender_val  age_imputed
# 0                     St Louis, MO           6        29.00
# 1  Montreal, PQ / Chesterville, ON           5         0.92
# 2  Montreal, PQ / Chesterville, ON           6         2.00
# 3  Montreal, PQ / Chesterville, ON           5        30.00
# 4  Montreal, PQ / Chesterville, ON           6        25.00

# %%
# Filtering Gotchas
titanic[(titanic.survived == 1) & (titanic.pclass == 1)]
# Out:
#      pclass  survived                                               name  \
# 0         1         1                      Allen, Miss. Elisabeth Walton
# 1         1         1                     Allison, Master. Hudson Trevor
# 5         1         1                                Anderson, Mr. Harry
# 6         1         1                  Andrews, Miss. Kornelia Theodosia
# 8         1         1      Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 11        1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# 12        1         1                      Aubart, Mme. Leontine Pauline
# 13        1         1                       Barber, Miss. Ellen "Nellie"
# 14        1         1               Barkworth, Mr. Algernon Henry Wilson
# 17        1         1    Baxter, Mrs. James (Helene DeLaudeniere Chaput)
# ..      ...       ...                                                ...
# 304       1         1   Warren, Mrs. Frank Manley (Anna Sophia Atkinson)
# 308       1         1              White, Mrs. John Stuart (Ella Holmes)
# 309       1         1                           Wick, Miss. Mary Natalie
# 311       1         1         Wick, Mrs. George Dennick (Mary Hitchcock)
# 314       1         1       Widener, Mrs. George Dunton (Eleanor Elkins)
# 315       1         1                           Willard, Miss. Constance
# 317       1         1                    Williams, Mr. Richard Norris II
# 319       1         1                          Wilson, Miss. Helen Alice
# 320       1         1                                  Woolner, Mr. Hugh
# 322       1         1                           Young, Miss. Marie Grice
#
#      gender    age  sibsp  parch    ticket    fare    cabin embarked  boat  \
# 0    female  29.00      0      0     24160  211.34       B5        S     2
# 1      male   0.92      1      2    113781  151.55  C22 C26        S    11
# 5      male  48.00      0      0     19952   26.55      E12        S     3
# 6    female  63.00      1      0     13502   77.96       D7        S    10
# 8    female  53.00      2      0     11769   51.48     C101        S     D
# 11   female  18.00      1      0  PC 17757  227.53  C62 C64        C     4
# 12   female  24.00      0      0  PC 17477   69.30      B35        C     9
# 13   female  26.00      0      0     19877   78.85      NaN        S     6
# 14     male  80.00      0      0     27042   30.00      A23        S     B
# 17   female  50.00      0      1  PC 17558  247.52  B58 B60        C     6
# ..      ...    ...    ...    ...       ...     ...      ...      ...   ...
# 304  female  60.00      1      0    110813   75.25      D37        C     5
# 308  female  55.00      0      0  PC 17760  135.63      C32        C     8
# 309  female  31.00      0      2     36928  164.87       C7        S     8
# 311  female  45.00      1      1     36928  164.87      NaN        S     8
# 314  female  50.00      1      1    113503  211.50      C80        C     4
# 315  female  21.00      0      0    113795   26.55      NaN        S  8 10
# 317    male  21.00      0      1  PC 17597   61.38      NaN        C     A
# 319  female  31.00      0      0     16966  134.50  E39 E41        C     3
# 320    male    NaN      0      0     19947   35.50      C52        S     D
# 322  female  36.00      0      0  PC 17760  135.63      C32        C     8
#
#      body                           home.dest  gender_val  age_imputed
# 0     NaN                        St Louis, MO           6        29.00
# 1     NaN     Montreal, PQ / Chesterville, ON           5         0.92
# 5     NaN                        New York, NY           5        48.00
# 6     NaN                          Hudson, NY           6        63.00
# 8     NaN                 Bayside, Queens, NY           6        53.00
# 11    NaN                        New York, NY           6        18.00
# 12    NaN                       Paris, France           6        24.00
# 13    NaN                                 NaN           6        26.00
# 14    NaN                       Hessle, Yorks           5        80.00
# 17    NaN                        Montreal, PQ           6        50.00
# ..    ...                                 ...         ...          ...
# 304   NaN                        Portland, OR           6        60.00
# 308   NaN  New York, NY / Briarcliff Manor NY           6        55.00
# 309   NaN                      Youngstown, OH           6        31.00
# 311   NaN                      Youngstown, OH           6        45.00
# 314   NaN                     Elkins Park, PA           6        50.00
# 315   NaN                          Duluth, MN           6        21.00
# 317   NaN    Geneva, Switzerland / Radnor, PA           5        21.00
# 319   NaN                                 NaN           6        31.00
# 320   NaN                     London, England           5        29.88
# 322   NaN       New York, NY / Washington, DC           6        36.00
#
# [200 rows x 16 columns]

# %%
# Let's now look at Distribution of Age and Survived
# Now look at survived data
g = sns.FacetGrid(titanic, row='gender', col='survived', sharex=True, sharey=True)
g.map(plt.hist, "age")

# %%
# Now, your turn - Can you do some plots with pclass (Passenger Class)

# %%
g = sns.FacetGrid(titanic, row = 'gender', col = 'pclass', sharex = True, sharey = False)
g.map(plt.hist, 'survived')
