# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

% matplotlib inline

import holoviews
from holoviews.interface import seaborn

holoviews.ipython.widgets.SelectionWidget.export_json=True
holoviews.ipython.widgets.SelectionWidget.server_url='http://philippjfr.com/ipynbs'

# %load_ext holoviews.ipython
# %view widgets svg
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-465-6597f82b93d5> in <module>()
#       5 get_ipython().magic(u'matplotlib inline')
#       6
# ----> 7 import holoviews
#       8 from holoviews.interface import seaborn
#       9
#
# ImportError: No module named holoviews

# %%
cols = ['age',
        'workclass',
        'fnlwgt',
        'education',
        'education_num',
        'marital_status',
        'occupation',
        'relationship',
        'race',
        'sex',
        'capital_gain',
        'capital_loss',
        'hours_per_week',
        'native_country',
        'income']
adult_df = pd.read_csv('http://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data',
                       header=0,names=cols,index_col=False)

# %%
plt.hexbin(adult_df.age, adult_df.hours_per_week, gridsize = (70, 20), bins = 'log', yscale = 'linear')
plt.show()

# %%
plt.hexbin(adult_df.age, adult_df.capital_gain, gridsize = (20, 5), bins = 'log')
plt.show()

# %%
plt.hexbin(adult_df.education_num, adult_df.capital_gain, gridsize = (20, 5), bins = 'log')
plt.show()

# %%
plt.hexbin(adult_df.education_num, adult_df.capital_gain, gridsize = (16, 4), bins = 'log')
plt.show()

# %%
plt.hexbin(adult_df.education_num, adult_df.capital_loss, gridsize = (16, 4), bins = 'log')
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(adult_df.capital_loss, adult_df.education_num, adult_df.age, c = 'b', alpha = .1)
plt.show()

# %%
N = 50
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = np.pi * (15 * np.random.rand(N))**2 # 0 to 15 point radiuses

plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.show()

# %%
import itertools

import numpy as np
import pandas as pd
from scipy import stats

np.random.seed(9221999)

import holoviews
from holoviews.interface import seaborn
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-460-6d95aad4a706> in <module>()
#       7 np.random.seed(9221999)
#       8
# ----> 9 import holoviews
#      10 from holoviews.interface import seaborn
#
# ImportError: No module named holoviews

# %%
plt.plot([1, 2, 3, 4])
plt.ylabel('some numbers')
plt.show()

# %%
plt.plot([1, 2, 3, 4],[1, 4, 9, 16], 'ro') # ro makes red dots
plt.axis([0, 6, 0, 20])
plt.show()

# %%
t = np.arange(0., 5., 0.2)
plt.plot(t, 3*t, 'r--', t, t**2, 'bs', t, .3*t**3, 'g^')
plt.show()

# %%
lines = plt.plot([1, 2, 3, 4], color = 'r')
plt.setp(lines)
# Out:
#   agg_filter: unknown
#   alpha: float (0.0 transparent through 1.0 opaque)
#   animated: [True | False]
#   antialiased or aa: [True | False]
#   axes: an :class:`~matplotlib.axes.Axes` instance
#   clip_box: a :class:`matplotlib.transforms.Bbox` instance
#   clip_on: [True | False]
#   clip_path: [ (:class:`~matplotlib.path.Path`,         :class:`~matplotlib.transforms.Transform`) |         :class:`~matplotlib.patches.Patch` | None ]
#   color or c: any matplotlib color
#   contains: a callable function
#   dash_capstyle: ['butt' | 'round' | 'projecting']
#   dash_joinstyle: ['miter' | 'round' | 'bevel']
#   dashes: sequence of on/off ink in points
#   drawstyle: ['default' | 'steps' | 'steps-pre' | 'steps-mid' |                   'steps-post']
#   figure: a :class:`matplotlib.figure.Figure` instance
#   fillstyle: ['full' | 'left' | 'right' | 'bottom' | 'top' | 'none']
#   gid: an id string
#   label: string or anything printable with '%s' conversion.
# ...

# %%
def f(t):
    return np.exp(-t) * np.cos(2*np.pi*t)

t1 = np.arange(0.0, 5.0, 0.1)
t2 = np.arange(0.0, 5.0, 0.02)

plt.figure(1) # optional
plt.subplot(2,1,1) #The subplot() command specifies numrows, numcols, fignum where fignum ranges from 1 to numrows*numcols
plt.plot(t1, f(t1), 'bo', t2, f(t2), 'k')

plt.subplot(2,1,1) # for (2,1,2) for seperate plots
plt.plot(t2, np.cos(2*np.pi*t2), 'r--')
plt.show()

# %%
plt.figure(1)                # the first figure
plt.subplot(211)             # the first subplot in the first figure
plt.plot([1,2,3])
plt.subplot(212)             # the second subplot in the first figure
plt.plot([4,5,6])


plt.figure(2)                # a second figure
plt.plot([4,5,6])            # creates a subplot(111) by default
plt.ylim(3.5, 6.5)


plt.figure(1)                # figure 1 current; subplot(212) still current
plt.subplot(211)             # make subplot(211) in figure1 current
plt.title('1,2,3')   # subplot 211 title

# %%
mu, sigma = 100, 15
x = mu + sigma * np.random.randn(10000)
#histogram of the data
n, bins, patches = plt.hist(x, 50, normed = 1, facecolor = 'b', alpha = .35)

plt.xlabel('IQ')
plt.ylabel('probability')
plt.title('Histogram of IQ')
plt.text(55, .025, r'$\mu = 100,\ \sigma=15$')
plt.axis([40, 160, 0, 0.03])
plt.grid(True)
plt.show()

# %%
plt.style.use('ggplot')
print plt.style.available
# set a style
plt.style.use('fivethirtyeight')
# Out:
# [u'dark_background', u'bmh', u'grayscale', u'ggplot', u'fivethirtyeight']

# %%
# set a temprary style
with plt.style.context(('dark_background')):
    plt.plot(np.sin(np.linspace(0, 2*np.pi)), 'r-o')

plt.show()

# %%
plt.plot(np.sin(np.linspace(0, 2*np.pi)))
plt.ylim(-2,2)
plt.xlabel('This is a Sin Wave',
           alpha = .5,
           bbox=dict(facecolor='white', edgecolor='gray'),
           color = 'b',
           family =  'cursive',
           rotation = 10,
           size = 20,
           x = .3,
           weight = 'heavy')
plt.show()

# %%
from matplotlib.legend_handler import HandlerLine2D

line1, = plt.plot([3,2,1], marker='o', label='Line 1')
line2, = plt.plot([1,2,3], marker='o', label='Line 2')

plt.legend(handler_map={line1: HandlerLine2D(numpoints=2)})

# %%
plt.hexbin(adult_df.age, adult_df['education_num'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-311-273314f4aba5> in <module>()
# ----> 1 plt.hexbin(adult_df.age, adult_df['education_num'])
#
# /Users/David/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1778             return self._getitem_multilevel(key)
#    1779         else:
# -> 1780             return self._getitem_column(key)
#    1781
#    1782     def _getitem_column(self, key):
#
# /Users/David/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    1785         # get column
#    1786         if self.columns.is_unique:
# -> 1787             return self._get_item_cache(key)
#    1788
#    1789         # duplicate columns & possible reduce dimensionaility
#
# /Users/David/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
# ...
